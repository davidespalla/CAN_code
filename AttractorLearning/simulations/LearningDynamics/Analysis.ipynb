# %%
# %pylab inline
import seaborn as sns
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
ma=load("s1/mJA.npy")
mb=load("s1/mJB.npy")
mab=load("s1/mJAB.npy")

# %%
t=asarray(range(len(ma)))

# %%
plot(t,ma,label="mJA")
plot(t,mb,label="mJB")
plot(t,mab,label="mJAB")
legend()

# %%
ma=load("s2/mJA.npy")
mb=load("s2/mJB.npy")
mab=load("s2/mJAB.npy")

# %%
t=asarray(range(len(ma)))

# %%
plot(t,ma,label="mJA")
plot(t,mb,label="mJB")
plot(t,mab,label="mJAB")
legend()

# %%
Jt=[]
for i in t:
    Jt.append(load("s1/J"+str(i)+".npy"))

# %%
Jnorm=[norm(x) for x in Jt]

# %%
scatter(t,Jnorm)
