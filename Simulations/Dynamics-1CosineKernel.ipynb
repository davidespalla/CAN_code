# %%
# %pylab inline
import cnn
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
Net=cnn.Network(300,2,1)

# %%
Net.BuildMaps()

# %%
Net.SetJ()

# %%
Net.SetV0(1)

# %%
Net.r.shape
# Out:
# (300, 2, 1)

# %%
scatter(Net.r.T[0][0],Net.V)

# %%
Net.EvolveDynamics(1,0.5)

# %%
scatter(Net.r.T[0][1],Net.V)
